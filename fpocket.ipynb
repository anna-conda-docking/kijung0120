# %% [markdown]
# <a href="https://colab.research.google.com/github/anna-conda-docking/kijung0120/blob/main/fpocket.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Discngine/fpocket.git
# %cd fpocket
# !make 
# !make install
# Out:
# Cloning into 'fpocket'...
# remote: Enumerating objects: 6099, done.
# remote: Counting objects: 100% (526/526), done.
# remote: Compressing objects: 100% (192/192), done.
# remote: Total 6099 (delta 344), reused 473 (delta 322), pack-reused 5573
# Receiving objects: 100% (6099/6099), 117.60 MiB | 20.87 MiB/s, done.
# Resolving deltas: 100% (3239/3239), done.
# Checking out files: 100% (3422/3422), done.
# /content/fpocket
# cd src/qhull/ && make
# make[1]: Entering directory '/content/fpocket/src/qhull'
# mkdir -p bin lib
# gcc -c -O3 -ansi -Isrc -fpic -Wall -Wcast-qual -Wextra -Wwrite-strings -Wshadow -o src/rbox/rbox.o src/rbox/rbox.c
# gcc -c -O3 -ansi -Isrc -fpic -Wall -Wcast-qual -Wextra -Wwrite-strings -Wshadow -o src/libqhullstatic/global.o src/libqhull/global.c
# gcc -c -O3 -ansi -Isrc -fpic -Wall -Wcast-qual -Wextra -Wwrite-strings -Wshadow -o src/libqhullstatic/stat.o src/libqhull/stat.c
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !wget https://files.rcsb.org/download/1EVE.pdb
# Out:
# --2022-07-27 04:13:40--  https://files.rcsb.org/download/1EVE.pdb
# Resolving files.rcsb.org (files.rcsb.org)... 132.249.210.222
# Connecting to files.rcsb.org (files.rcsb.org)|132.249.210.222|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/octet-stream]
# Saving to: ‘1EVE.pdb.1’
#
# 1EVE.pdb.1              [ <=>                ] 421.69K  --.-KB/s    in 0.05s
#
# 2022-07-27 04:13:40 (8.21 MB/s) - ‘1EVE.pdb.1’ saved [431811]

# %%
# !fpocket -f 1EVE.pdb
# Out:
# ***** POCKET HUNTING BEGINS *****
# ***** POCKET HUNTING ENDS *****

# %%
# !tar czvf 1EVE_out.tar.gz 1EVE_out
# Out:
# 1EVE_out/
# 1EVE_out/1EVE_pockets.pqr
# 1EVE_out/1EVE.pml
# 1EVE_out/1EVE_PYMOL.sh
# 1EVE_out/1EVE.tcl
# 1EVE_out/1EVE_out.pdb
# 1EVE_out/1EVE_VMD.sh
# 1EVE_out/pockets/
# 1EVE_out/pockets/pocket17_atm.pdb
# 1EVE_out/pockets/pocket17_vert.pqr
# 1EVE_out/pockets/pocket15_vert.pqr
# 1EVE_out/pockets/pocket14_atm.pdb
# 1EVE_out/pockets/pocket3_atm.pdb
# 1EVE_out/pockets/pocket19_atm.pdb
# 1EVE_out/pockets/pocket20_atm.pdb
# 1EVE_out/pockets/pocket10_vert.pqr
# 1EVE_out/pockets/pocket13_atm.pdb
# 1EVE_out/pockets/pocket2_vert.pqr
# 1EVE_out/pockets/pocket4_vert.pqr
# 1EVE_out/pockets/pocket2_atm.pdb
# 1EVE_out/pockets/pocket5_atm.pdb
# 1EVE_out/pockets/pocket19_vert.pqr
# 1EVE_out/pockets/pocket18_vert.pqr
# 1EVE_out/pockets/pocket1_atm.pdb
# 1EVE_out/pockets/pocket6_atm.pdb
# 1EVE_out/pockets/pocket14_vert.pqr
# 1EVE_out/pockets/pocket12_atm.pdb
# 1EVE_out/pockets/pocket13_vert.pqr
# 1EVE_out/pockets/pocket3_vert.pqr
# 1EVE_out/pockets/pocket8_atm.pdb
# ...

# %%
from google.colab import files
files.download("1EVE_out.tar.gz")
